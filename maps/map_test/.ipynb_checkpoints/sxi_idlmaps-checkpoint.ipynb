# %%
from __future__ import print_function, division
from datetime import timedelta
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.colors as colors

# could use the sunpy colormaps instead
import sunpy.cm as scm

from matplotlib.colors import LogNorm
from pylab import figure, cm
# %matplotlib inline

import astropy.time
from astropy.io import fits
from astropy import units as u

from sunpy import sun
import sunpy.map
# Out:
# WARNING: AstropyDeprecationWarning: astropy.utils.compat.odict.OrderedDict is now deprecated - import OrderedDict from the collections module instead [astropy.utils.compat.odict]

# %%
# Let's start by trying to load in the SXI fits outputted but map2fit.pro
#https://hesperia.gsfc.nasa.gov/ssw/gen/idl/maps/map2fits.pro

infile='oSXI_20150901_033615.fits'
sxi_map = sunpy.map.Map(infile)
sxi_map.peek(draw_limb=True,draw_grid=15*u.deg)
# Does not work
# Out:
# /Users/iain/anaconda/lib/python3.6/site-packages/sunpy/map/mapbase.py:675: Warning: Unknown value for CUNIT1
#   warnings.warn("Unknown value for "+meta_property.upper(), Warning)
# /Users/iain/anaconda/lib/python3.6/site-packages/sunpy/map/mapbase.py:675: Warning: Unknown value for CUNIT2
#   warnings.warn("Unknown value for "+meta_property.upper(), Warning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/iain/anaconda/lib/python3.6/site-packages/astropy/units/format/generic.py in _do_parse(cls, s, debug)
#     469             # is just a single unit name
# --> 470             return cls._parse_unit(s, detailed_exception=False)
#     471         except ValueError as e:
#
# /Users/iain/anaconda/lib/python3.6/site-packages/astropy/units/format/generic.py in _parse_unit(cls, s, detailed_exception)
#     449         else:
# --> 450             raise ValueError()
#     451
#
# ValueError:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /Users/iain/anaconda/lib/python3.6/site-packages/astropy/units/format/generic.py in _get_unit(cls, t)
#     430         try:
# --> 431             return cls._parse_unit(t.value)
#     432         except ValueError as e:
#
# /Users/iain/anaconda/lib/python3.6/site-packages/astropy/units/format/generic.py in _parse_unit(cls, s, detailed_exception)
#     447                 '{0} is not a valid unit. {1}'.format(
# --> 448                     s, did_you_mean(s, registry)))
#     449         else:
#
# ValueError: arcsecs is not a valid unit. Did you mean arcsec?
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /Users/iain/anaconda/lib/python3.6/site-packages/astropy/units/core.py in __call__(self, s, represents, format, namespace, doc, parse_strict)
#    1827             try:
# -> 1828                 return f.parse(s)
#    1829             except Exception as e:
#
# /Users/iain/anaconda/lib/python3.6/site-packages/astropy/units/format/generic.py in parse(cls, s, debug)
#     456
# --> 457         result = cls._do_parse(s, debug=debug)
#     458         if s.count('/') > 1:
#
# /Users/iain/anaconda/lib/python3.6/site-packages/astropy/units/format/generic.py in _do_parse(cls, s, debug)
#     472             try:
# --> 473                 return cls._parser.parse(s, lexer=cls._lexer, debug=debug)
#     474             except ValueError as e:
#
# /Users/iain/anaconda/lib/python3.6/site-packages/astropy/extern/ply/yacc.py in parse(self, input, lexer, debug, tracking, tokenfunc)
#     330         else:
# --> 331             return self.parseopt_notrack(input, lexer, debug, tracking, tokenfunc)
#     332
#
# /Users/iain/anaconda/lib/python3.6/site-packages/astropy/extern/ply/yacc.py in parseopt_notrack(self, input, lexer, debug, tracking, tokenfunc)
#    1060                     if not lookaheadstack:
# -> 1061                         lookahead = get_token()     # Get the next token
#    1062                     else:
#
# /Users/iain/anaconda/lib/python3.6/site-packages/astropy/extern/ply/lex.py in token(self)
#     349
# --> 350                 newtok = func(tok)
#     351
#
# /Users/iain/anaconda/lib/python3.6/site-packages/astropy/units/format/generic.py in t_UNIT(t)
#     148             r"%|([YZEPTGMkhdcmunpfazy]?'((?!\d)\w)+')|((?!\d)\w)+"
# --> 149             t.value = cls._get_unit(t)
#     150             return t
#
# /Users/iain/anaconda/lib/python3.6/site-packages/astropy/units/format/generic.py in _get_unit(cls, t)
#     434                 "At col {0}, {1}".format(
# --> 435                     t.lexpos, six.text_type(e)))
#     436
#
# ValueError: At col 0, arcsecs is not a valid unit. Did you mean arcsec?
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-7a4d131afa94> in <module>()
#       5 sxi_map = sunpy.map.Map(infile)
#       6 plt.figure(figsize=(10, 8))
# ----> 7 sxi_map.peek(draw_limb=True,draw_grid=15*u.deg)
#       8 # Does not work
#
# /Users/iain/anaconda/lib/python3.6/site-packages/sunpy/visualization/visualization.py in fn_itoggle(*args, **kwargs)
#      27         def fn_itoggle(*args, **kwargs):
#      28             pyplot.ioff()
# ---> 29             ret = fn(*args, **kwargs)
#      30             pyplot.ion()
#      31             return ret
#
# /Users/iain/anaconda/lib/python3.6/site-packages/sunpy/map/mapbase.py in peek(self, draw_limb, draw_grid, colorbar, basic_plot, **matplot_args)
#    1533         # Normal plot
#    1534         else:
# -> 1535             axes = wcsaxes_compat.gca_wcs(self.wcs)
#    1536
#    1537         im = self.plot(axes=axes, **matplot_args)
#
# /Users/iain/anaconda/lib/python3.6/site-packages/sunpy/map/mapbase.py in wcs(self)
#     235         # Make these a quantity array to prevent the numpy setting element of
#     236         # array with sequence error.
# --> 237         w2.wcs.cdelt = u.Quantity(self.scale)
#     238         w2.wcs.crval = u.Quantity(self.reference_coordinate)
#     239         w2.wcs.ctype = self.coordinate_system
#
# /Users/iain/anaconda/lib/python3.6/site-packages/sunpy/map/mapbase.py in scale(self)
#     577         """Image scale along the x and y axes in units/pixel (i.e. cdelt1, cdelt2)"""
#     578         #TODO: Fix this if only CDi_j matrix is provided
# --> 579         return Pair(self.meta.get('cdelt1', 1.) * self.spatial_units.x / u.pixel,
#     580                     self.meta.get('cdelt2', 1.) * self.spatial_units.y / u.pixel)
#     581
#
# /Users/iain/anaconda/lib/python3.6/site-packages/sunpy/map/mapbase.py in spatial_units(self)
#     583     def spatial_units(self):
#     584         """Image coordinate units along the x and y axes (i.e. cunit1, cunit2)."""
# --> 585         return Pair(u.Unit(self.meta.get('cunit1', 'arcsec')),
#     586                     u.Unit(self.meta.get('cunit2', 'arcsec')))
#     587
#
# /Users/iain/anaconda/lib/python3.6/site-packages/astropy/units/core.py in __call__(self, s, represents, format, namespace, doc, parse_strict)
#    1840                            .format(s, format_clause, six.text_type(e)))
#    1841                     if parse_strict == 'raise':
# -> 1842                         raise ValueError(msg)
#    1843                     elif parse_strict == 'warn':
#    1844                         warnings.warn(msg, UnitsWarning)
#
# ValueError: 'arcsecs' did not parse as unit: At col 0, arcsecs is not a valid unit. Did you mean arcsec?

# %%
infile2='SXI_20150901_033615.fits'

sxi_map = sunpy.map.Map(infile2)

sxi_map.peek(draw_limb=True,draw_grid=15*u.deg)
# sxi_map.meta
# Out:
# /Users/iain/anaconda/lib/python3.6/site-packages/sunpy/wcs/wcs.py:232: RuntimeWarning: invalid value encountered in sqrt
#   z = np.sqrt(rsun_meters ** 2 - x ** 2 - y ** 2)
# /Users/iain/anaconda/lib/python3.6/site-packages/matplotlib/figure.py:403: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
# So manually load in the file and set the data and header
# fitsin = fits.open(infile)
# data=fitsin[0].data
# hdr=fitsin[0].header

# obs_time=hdr['date_obs']

# # Have I got everything?
# header = {'cdelt1': hdr['cdelt1'],'cdelt2': hdr['cdelt2'],
#           'instrume':'SXI','detector':'SXI',
#           'xcen':hdr['xcen'],'ycen':hdr['ycen'],'telescop':hdr['telescop'],
#           'exptime':hdr['exptime'],'date_obs':hdr['date_obs'],'wavelnth':12,
#           'crpix1':hdr['crpix1'],'crpix2':hdr['crpix2'],
# #           to stop getting warning about missing metadata about where observer is
#           'HGLT_OBS': 0,'HGLN_OBS': 0,
#           'RSUN_OBS': sun.solar_semidiameter_angular_size(obs_time).value,
#           'RSUN_REF': sun.constants.radius.value,
#           'DSUN_OBS': sun.sunearth_distance(obs_time).value*u.astrophys.au,
#          }
# sxi_map = sunpy.map.Map(data, header)

sxi_map.plot_settings['cmap'] = scm.get_cmap('stereohi1')
sxi_map.plot_settings['norm'] = colors.PowerNorm(gamma=0.2,vmax=5e2)

matplotlib.rcParams['font.size'] = 20

fig = plt.figure(figsize=(10, 8))
ax = plt.subplot()
sxi_map.plot()
sxi_map.draw_limb(color='white',linewidth=2,linestyle='dashed')  
# Like nustar map the grid is not working
sxi_map.draw_grid(color='white',linewidth=2,linestyle='dotted')

title_obsdate='{:.19}'.format('{:%Y-%m-%d %H:%M:%s}'.format(sxi_map.date))

ax.set_title('GOES/SXI Be12A '+title_obsdate)
ax.set_ylabel('y [arcsec]')
ax.set_xlabel('x [arcsec]')
plt.colorbar(fraction=0.04, pad=0.1,label='DN')
plt.show()

# sxi_map.peek(basic_plot=True)
# Out:
# /anaconda/lib/python3.6/site-packages/sunpy/map/mapbase.py:1604: Warning: WCSAxes is installed but not being used. Plots may not have the expected behaviour.
#   Warning)
# /anaconda/lib/python3.6/site-packages/sunpy/wcs/wcs.py:232: RuntimeWarning: invalid value encountered in sqrt
#   z = np.sqrt(rsun_meters ** 2 - x ** 2 - y ** 2)

# %%
rangex = u.Quantity([-1200*u.arcsec, -200 * u.arcsec])
rangey = u.Quantity([-1200 * u.arcsec, -200 * u.arcsec])
ssxi_map = sxi_map.submap(rangex, rangey)

fig = plt.figure(figsize=(10, 8))
ax = plt.subplot()
ssxi_map.plot()
ssxi_map.draw_limb(color='white',linewidth=2,linestyle='dashed')   
ssxi_map.draw_grid(color='white',linewidth=2,linestyle='dotted')

title_obsdate='{:.19}'.format('{:%Y-%m-%d %H:%M:%s}'.format(ssxi_map.date))

ax.set_title('GOES/SXI Be12A '+title_obsdate)
ax.set_ylabel('y [arcsec]')
ax.set_xlabel('x [arcsec]')
plt.colorbar(fraction=0.04, pad=0.1,label='DN')
plt.show()
# Out:
# /anaconda/lib/python3.6/site-packages/sunpy/map/mapbase.py:1604: Warning: WCSAxes is installed but not being used. Plots may not have the expected behaviour.
#   Warning)
# /anaconda/lib/python3.6/site-packages/sunpy/wcs/wcs.py:232: RuntimeWarning: invalid value encountered in sqrt
#   z = np.sqrt(rsun_meters ** 2 - x ** 2 - y ** 2)
